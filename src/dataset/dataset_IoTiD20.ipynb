# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv("IoTiD20.zip")

# %%
df
# Out:
#                                          Flow_ID          Src_IP  Src_Port  \
# 0         192.168.0.13-192.168.0.16-9020-49784-6    192.168.0.13      9020
# 1         192.168.0.13-192.168.0.16-9020-52717-6    192.168.0.16     52717
# 2         192.168.0.13-192.168.0.16-9020-53190-6    192.168.0.16     53190
# 3       192.168.0.24-111.47.222.205-19604-7447-6  111.47.222.205      7447
# 4         192.168.0.13-192.168.0.16-9020-49784-6    192.168.0.13      9020
# ...                                          ...             ...       ...
# 176462   192.168.0.24-223.39.118.176-50722-443-6    192.168.0.24     50722
# 176463  192.168.0.13-192.168.0.16-56361-10101-17    192.168.0.13     56361
# 176464    192.168.0.13-222.215.77.148-554-7463-6  222.215.77.148      7463
# 176465  151.101.230.110-192.168.0.24-443-52779-6    192.168.0.24     52779
# 176466    192.168.0.13-192.168.0.16-9020-52717-6    192.168.0.16     52717
#
#                  Dst_IP  Dst_Port  Protocol               Timestamp  \
# 0          192.168.0.16     49784         6  20/05/2019 04:59:15 AM
# 1          192.168.0.13      9020         6  11/07/2019 01:21:53 AM
# 2          192.168.0.13      9020         6  31/05/2019 03:18:59 AM
# 3          192.168.0.24     19604         6  04/06/2019 11:44:00 PM
# 4          192.168.0.16     49784         6  20/05/2019 04:58:59 AM
# ...                 ...       ...       ...                     ...
# 176462   223.39.118.176       443         6  03/06/2019 04:01:50 AM
# 176463     192.168.0.16     10101        17  25/07/2019 03:23:43 AM
# 176464     192.168.0.13       554         6  26/05/2019 10:11:10 PM
# 176465  151.101.230.110       443         6  03/06/2019 04:00:02 AM
# 176466     192.168.0.13      9020         6  11/07/2019 01:16:15 AM
#
#         Flow_Duration  Tot_Fwd_Pkts  Tot_Bwd_Pkts  ...  Active_Std  \
# 0                 429             4             1  ...         0.0
# 1                 151             2             1  ...         0.0
# 2                  81             1             1  ...         0.0
# 3                1109             0             2  ...         0.0
# 4                 109             1             1  ...         0.0
# ...               ...           ...           ...  ...         ...
# 176462            124             0             2  ...         0.0
# 176463            173             1             1  ...         0.0
# 176464           6838             0             2  ...         0.0
# 176465            166             0             2  ...         0.0
# 176466             73             0             2  ...         0.0
#
#         Active_Max  Active_Min  Idle_Mean   Idle_Std  Idle_Max  Idle_Min  \
# 0              0.0         0.0     107.25  36.206583     149.0      75.0
# 1              0.0         0.0      75.50   2.121320      77.0      74.0
# 2              0.0         0.0      81.00   0.000000      81.0      81.0
# 3              0.0         0.0    1109.00   0.000000    1109.0    1109.0
# 4              0.0         0.0     109.00   0.000000     109.0     109.0
# ...            ...         ...        ...        ...       ...       ...
# 176462         0.0         0.0     124.00   0.000000     124.0     124.0
# 176463         0.0         0.0     173.00   0.000000     173.0     173.0
# 176464         0.0         0.0    6838.00   0.000000    6838.0    6838.0
# 176465         0.0         0.0     166.00   0.000000     166.0     166.0
# 176466         0.0         0.0      73.00   0.000000      73.0      73.0
#
#           Label                Cat             Sub_Cat
# 0        Normal             Normal              Normal
# 1       Anomaly               Scan       Scan Hostport
# 2       Anomaly  MITM ARP Spoofing   MITM ARP Spoofing
# 3       Anomaly                DoS     DoS-Synflooding
# 4        Normal             Normal              Normal
# ...         ...                ...                 ...
# 176462  Anomaly  MITM ARP Spoofing   MITM ARP Spoofing
# 176463  Anomaly              Mirai  Mirai-UDP Flooding
# 176464  Anomaly                DoS     DoS-Synflooding
# 176465  Anomaly  MITM ARP Spoofing   MITM ARP Spoofing
# 176466  Anomaly               Scan        Scan Port OS
#
# [176467 rows x 86 columns]

# %%
output = 'Cat'

# %%
df[output].unique()
# Out:
# array(['Mirai', 'MITM ARP Spoofing', 'Scan', 'Normal', 'DoS'],
#       dtype=object)

# %%
df[output].value_counts()
# Out:
# Cat
# Mirai                299264
# Scan                  54222
# DoS                   42769
# Normal                28913
# MITM ARP Spoofing     25395
# Name: count, dtype: int64

# %%
col_1 = ['Mirai']
col_2 = ['Scan', 'Normal', 'DoS', 'MITM ARP Spoofing']

# %%
df_1 = df[df[output].isin(col_1)] 
df_2 = df[df[output].isin(col_2)]

# %%
df_1[output].count(), df_2[output].count()
# Out:
# (33568, 21022)

# %%
df_1[output].value_counts()
# Out:
# Cat
# Mirai    33568
# Name: count, dtype: int64

# %%
df_2[output].value_counts()
# Out:
# Cat
# Scan                 54222
# DoS                  42769
# Normal               28913
# MITM ARP Spoofing    25395
# Name: count, dtype: int64

# %%
def csv_save_zip(df, filename):
    compression_options = dict(method='zip', archive_name=f'{filename}.csv')
    df.to_csv(f'{filename}.zip', compression=compression_options, index=False)

# %%
csv_save_zip(df_1, 'training-set_0')

# %%
csv_save_zip(df_2, 'training-set_1')

# %%
x = df
y = df[output]
x, _x, y, _y = train_test_split(x, y, random_state=189, test_size=0.50, stratify=y)

# %%
x
# Out:
#                                          Flow_ID           Src_IP  Src_Port  \
# 16129   192.168.0.13-192.168.0.16-10000-10101-17     192.168.0.13     10000
# 20681      192.168.0.13-222.79.173.75-554-5850-6    222.79.173.75      5850
# 31940   192.168.0.24-222.239.240.107-57711-443-6     192.168.0.24     57711
# 157059  192.168.0.24-111.124.106.45-19604-7151-6   111.124.106.45      7151
# 82241     192.168.0.13-192.168.0.16-9020-52704-6     192.168.0.16     52704
# ...                                          ...              ...       ...
# 1769     192.168.0.13-222.254.233.116-554-3110-6  222.254.233.116      3110
# 5302      192.168.0.13-192.168.0.16-9020-49784-6     192.168.0.13      9020
# 53235     192.168.0.13-192.168.0.16-9020-52727-6     192.168.0.16     52727
# 99188   192.168.0.13-192.168.0.16-10000-10101-17     192.168.0.13     10000
# 20488     192.168.0.13-192.168.0.16-9020-52727-6     192.168.0.16     52727
#
#                  Dst_IP  Dst_Port  Protocol               Timestamp  \
# 16129      192.168.0.16     10101        17  25/07/2019 03:25:54 AM
# 20681      192.168.0.13       554         6  26/05/2019 10:11:08 PM
# 31940   222.239.240.107       443         6  03/06/2019 03:53:48 AM
# 157059     192.168.0.24     19604         6  04/06/2019 11:44:24 PM
# 82241      192.168.0.13      9020         6  11/07/2019 01:12:21 AM
# ...                 ...       ...       ...                     ...
# 1769       192.168.0.13       554         6  26/05/2019 10:06:52 PM
# 5302       192.168.0.16     49784         6  20/05/2019 04:58:01 AM
# 53235      192.168.0.13      9020         6  11/07/2019 01:25:02 AM
# 99188      192.168.0.16     10101        17  25/07/2019 03:25:06 AM
# 20488      192.168.0.13      9020         6  11/07/2019 01:24:54 AM
#
#         Flow_Duration  Tot_Fwd_Pkts  Tot_Bwd_Pkts  ...  Active_Std  \
# 16129             190             1             1  ...         0.0
# 20681            3713             0             2  ...         0.0
# 31940              76             0             2  ...         0.0
# 157059            717             0             2  ...         0.0
# 82241             113             0             2  ...         0.0
# ...               ...           ...           ...  ...         ...
# 1769             4006             0             2  ...         0.0
# 5302              359             0             2  ...         0.0
# 53235             128             0             2  ...         0.0
# 99188             119             1             1  ...         0.0
# 20488             145             0             3  ...         0.0
#
#         Active_Max  Active_Min  Idle_Mean  Idle_Std  Idle_Max  Idle_Min  \
# 16129          0.0         0.0      190.0  0.000000     190.0     190.0
# 20681          0.0         0.0     3713.0  0.000000    3713.0    3713.0
# 31940          0.0         0.0       76.0  0.000000      76.0      76.0
# 157059         0.0         0.0        0.0  0.000000       0.0       0.0
# 82241          0.0         0.0      113.0  0.000000     113.0     113.0
# ...            ...         ...        ...       ...       ...       ...
# 1769           0.0         0.0     4006.0  0.000000    4006.0    4006.0
# 5302           0.0         0.0      359.0  0.000000     359.0     359.0
# 53235          0.0         0.0      128.0  0.000000     128.0     128.0
# 99188          0.0         0.0      119.0  0.000000     119.0     119.0
# 20488          0.0         0.0       72.5  0.707107      73.0      72.0
#
#           Label                Cat              Sub_Cat
# 16129   Anomaly              Mirai  Mirai-HTTP Flooding
# 20681   Anomaly                DoS      DoS-Synflooding
# 31940   Anomaly  MITM ARP Spoofing    MITM ARP Spoofing
# 157059  Anomaly                DoS      DoS-Synflooding
# 82241   Anomaly               Scan        Scan Hostport
# ...         ...                ...                  ...
# 1769    Anomaly                DoS      DoS-Synflooding
# 5302     Normal             Normal               Normal
# 53235   Anomaly               Scan         Scan Port OS
# 99188   Anomaly              Mirai    Mirai-Ackflooding
# 20488   Anomaly               Scan         Scan Port OS
#
# [88233 rows x 86 columns]

# %%
_x
# Out:
#                                          Flow_ID          Src_IP  Src_Port  \
# 128623    192.168.0.13-192.168.0.16-9020-52727-6    192.168.0.16     52727
# 7546      192.168.0.13-222.93.131.242-554-7031-6  222.93.131.242      7031
# 168390   192.168.0.24-211.188.147.64-56247-443-6    192.168.0.24     56247
# 29918     192.168.0.13-192.168.0.16-9020-52717-6    192.168.0.16     52717
# 18747   192.168.0.24-210.89.164.90-60215-8899-17    192.168.0.24     60215
# ...                                          ...             ...       ...
# 56131     192.168.0.13-192.168.0.16-9020-52727-6    192.168.0.16     52727
# 174464    192.168.0.13-192.168.0.16-9020-49784-6    192.168.0.13      9020
# 176275  192.168.0.13-192.168.0.16-56361-10101-17    192.168.0.13     56361
# 78877     192.168.0.13-192.168.0.16-9020-52739-6    192.168.0.16     52739
# 171082    192.168.0.13-192.168.0.16-9020-53264-6    192.168.0.16     53264
#
#                 Dst_IP  Dst_Port  Protocol               Timestamp  \
# 128623    192.168.0.13      9020         6  11/07/2019 01:24:06 AM
# 7546      192.168.0.13       554         6  26/05/2019 10:11:17 PM
# 168390  211.188.147.64       443         6  03/06/2019 04:03:39 AM
# 29918     192.168.0.13      9020         6  11/07/2019 01:16:43 AM
# 18747    210.89.164.90      8899        17  25/07/2019 03:21:09 AM
# ...                ...       ...       ...                     ...
# 56131     192.168.0.13      9020         6  11/07/2019 01:24:01 AM
# 174464    192.168.0.16     49784         6  20/05/2019 04:58:07 AM
# 176275    192.168.0.16     10101        17  25/07/2019 03:24:20 AM
# 78877     192.168.0.13      9020         6  11/07/2019 01:27:26 AM
# 171082    192.168.0.13      9020         6  31/05/2019 04:08:02 AM
#
#         Flow_Duration  Tot_Fwd_Pkts  Tot_Bwd_Pkts  ...  Active_Std  \
# 128623            118             0             2  ...         0.0
# 7546             4641             0             2  ...         0.0
# 168390            142             1             1  ...         0.0
# 29918             162             0             3  ...         0.0
# 18747             193             1             1  ...         0.0
# ...               ...           ...           ...  ...         ...
# 56131              73             0             2  ...         0.0
# 174464            237             2             1  ...         0.0
# 176275             72             1             1  ...         0.0
# 78877             119             0             2  ...         0.0
# 171082             72             0             2  ...         0.0
#
#         Active_Max  Active_Min  Idle_Mean  Idle_Std  Idle_Max  Idle_Min  \
# 128623         0.0         0.0      118.0  0.000000     118.0     118.0
# 7546           0.0         0.0     4641.0  0.000000    4641.0    4641.0
# 168390         0.0         0.0      142.0  0.000000     142.0     142.0
# 29918          0.0         0.0       81.0  8.485281      87.0      75.0
# 18747          0.0         0.0      193.0  0.000000     193.0     193.0
# ...            ...         ...        ...       ...       ...       ...
# 56131          0.0         0.0       73.0  0.000000      73.0      73.0
# 174464         0.0         0.0      118.5  3.535534     121.0     116.0
# 176275         0.0         0.0       72.0  0.000000      72.0      72.0
# 78877          0.0         0.0      119.0  0.000000     119.0     119.0
# 171082         0.0         0.0       72.0  0.000000      72.0      72.0
#
#           Label                Cat             Sub_Cat
# 128623  Anomaly               Scan        Scan Port OS
# 7546    Anomaly                DoS     DoS-Synflooding
# 168390  Anomaly  MITM ARP Spoofing   MITM ARP Spoofing
# 29918   Anomaly               Scan        Scan Port OS
# 18747   Anomaly              Mirai  Mirai-UDP Flooding
# ...         ...                ...                 ...
# 56131   Anomaly               Scan        Scan Port OS
# 174464   Normal             Normal              Normal
# 176275  Anomaly              Mirai  Mirai-UDP Flooding
# 78877   Anomaly               Scan       Scan Hostport
# 171082  Anomaly  MITM ARP Spoofing   MITM ARP Spoofing
#
# [88234 rows x 86 columns]

# %%
csv_save_zip(x, 'training-set_0')

# %%
csv_save_zip(_x, 'training-set_1')

# %%
x['type'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'type'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 x['type'].value_counts()
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:4090, in DataFrame.__getitem__(self, key)
#    4088 if self.columns.nlevels > 1:
#    4089     return self._getitem_multilevel(key)
# -> 4090 indexer = self.columns.get_loc(key)
#    4091 if is_integer(indexer):
#    4092     indexer = [indexer]
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'type'

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
x_test = x[['Protocol', 'Flow_Duration', 'Tot_Fwd_Pkts', 'Tot_Bwd_Pkts',
       'TotLen_Fwd_Pkts', 'TotLen_Bwd_Pkts', 'Fwd_Pkt_Len_Max',
       'Fwd_Pkt_Len_Min', 'Fwd_Pkt_Len_Mean', 'Fwd_Pkt_Len_Std',
       'Bwd_Pkt_Len_Max', 'Bwd_Pkt_Len_Min', 'Bwd_Pkt_Len_Mean',
       'Bwd_Pkt_Len_Std', 'Flow_Byts/s', 'Flow_Pkts/s', 'Flow_IAT_Mean',
       'Flow_IAT_Std', 'Flow_IAT_Max', 'Flow_IAT_Min', 'Fwd_IAT_Tot',
       'Fwd_IAT_Mean', 'Fwd_IAT_Std', 'Fwd_IAT_Min', 'Bwd_IAT_Tot',
       'Bwd_IAT_Mean', 'Bwd_IAT_Std', 'Bwd_IAT_Min', 'Fwd_PSH_Flags',
       'Bwd_PSH_Flags', 'Fwd_URG_Flags', 'Bwd_URG_Flags', 'Fwd_Header_Len',
       'Bwd_Header_Len', 'Fwd_Pkts/s', 'Bwd_Pkts/s', 'Pkt_Len_Min',
       'Pkt_Len_Max', 'Pkt_Len_Mean', 'Pkt_Len_Std', 'Pkt_Len_Var',
       'FIN_Flag_Cnt', 'SYN_Flag_Cnt', 'RST_Flag_Cnt', 'ACK_Flag_Cnt',
       'URG_Flag_Cnt', 'CWE_Flag_Count', 'ECE_Flag_Cnt', 'Down/Up_Ratio',
        'Fwd_Byts/b_Avg', 'Fwd_Pkts/b_Avg', 'Fwd_Blk_Rate_Avg', 'Bwd_Byts/b_Avg',
       'Bwd_Pkts/b_Avg', 'Bwd_Blk_Rate_Avg', 'Init_Fwd_Win_Byts', 'Init_Bwd_Win_Byts',
       'Fwd_Act_Data_Pkts', 'Fwd_Seg_Size_Min', 'Active_Mean', 'Active_Std',
       'Active_Min', 'Idle_Mean', 'Idle_Std', 'Idle_Min']]

# %%
import numpy as np

# %%
x_test.replace([np.inf, -np.inf], np.nan, inplace=True)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_12284\718148394.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x_test.replace([np.inf, -np.inf], np.nan, inplace=True)

# %%
scaler = MinMaxScaler()
x_test = scaler.fit_transform(x_test)

# %%
x_test
# Out:
# array([[1.00000000e+00, 1.00016003e-04, 5.43478261e-03, ...,
#         1.00027007e-04, 0.00000000e+00, 1.00027007e-04],
#        [3.52941176e-01, 1.17018723e-03, 0.00000000e+00, ...,
#         1.17031599e-03, 0.00000000e+00, 1.17031599e-03],
#        [3.52941176e-01, 2.25036006e-03, 0.00000000e+00, ...,
#         7.50202555e-04, 6.59824887e-05, 7.20194453e-04],
#        ...,
#        [3.52941176e-01, 8.00128020e-04, 5.43478261e-03, ...,
#         8.00216058e-04, 0.00000000e+00, 8.00216058e-04],
#        [1.00000000e+00, 8.30132821e-04, 5.43478261e-03, ...,
#         8.30224161e-04, 0.00000000e+00, 8.30224161e-04],
#        [3.52941176e-01, 8.50136022e-04, 0.00000000e+00, ...,
#         8.50229562e-04, 0.00000000e+00, 8.50229562e-04]])
