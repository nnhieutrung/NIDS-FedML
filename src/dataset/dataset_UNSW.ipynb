# %%
import pandas as pd

# %%
df = pd.read_csv("./UNSW_NB15.zip")

# %%
from sklearn.model_selection import train_test_split

# %%
output = 'attack_cat'

# %%
df[output].unique()
# Out:
# array(['Normal', 'Reconnaissance', 'Backdoor', 'DoS', 'Exploits',
#        'Analysis', 'Fuzzers', 'Worms', 'Shellcode', 'Generic'],
#       dtype=object)

# %%
df[output].value_counts()
# Out:
# attack_cat
# Normal            37000
# Generic           18871
# Exploits          11132
# Fuzzers            6062
# DoS                4089
# Reconnaissance     3496
# Analysis            677
# Backdoor            583
# Shellcode           378
# Worms                44
# Name: count, dtype: int64

# %%
col_1 = ['Analysis', 'Reconnaissance', 'Worms', 'Shellcode', 'Generic']
col_2 = ['Fuzzers',  'Backdoor', 'DoS', 'Exploits']

# %%
df_1 = df[df[output].isin(col_1)] 
df_2 = df[df[output].isin(col_2)]

# %%
df_3 = df[df[output] == 'Normal']

# %%
midpoint = len(df_3) // 2

df_1 = pd.concat([df_1, df_3.iloc[:midpoint]], axis=False)
df_2 = pd.concat([df_2, df_3.iloc[:midpoint]], axis=False)

# %%
df_1[output].count(), df_2[output].count()
# Out:
# (41966, 40366)

# %%
df_1[output].value_counts()
# Out:
# attack_cat
# Generic           18871
# Normal            18500
# Reconnaissance     3496
# Analysis            677
# Shellcode           378
# Worms                44
# Name: count, dtype: int64

# %%
df_2[output].value_counts()
# Out:
# attack_cat
# Normal      18500
# Exploits    11132
# Fuzzers      6062
# DoS          4089
# Backdoor      583
# Name: count, dtype: int64

# %%
def csv_save_zip(df, filename):
    compression_options = dict(method='zip', archive_name=f'{filename}.csv')
    df.to_csv(f'{filename}.zip', compression=compression_options, index=False)

# %%
csv_save_zip(df_1, 'training-set_0')

# %%
csv_save_zip(df_2, 'training-set_1')

# %%
x = df
y = df[output]
x, _x, y, _y = train_test_split(x, y, random_state=189, test_size=0.05, stratify=y)

# %%
x
# Out:
#           id       dur proto service state  spkts  dpkts  sbytes  dbytes  \
# 1705    1706  0.000009  cftp       -   INT      2      0     200       0
# 10166  10167  0.265486   tcp    http   FIN     14      8    7590    3100
# 72936  72937  2.286198   tcp       -   FIN     10      8     754     354
# 38444  38445  0.001109   udp     dns   CON      2      2     130     162
# 19574  19575  0.000001   udp     dns   INT      2      0     114       0
# ...      ...       ...   ...     ...   ...    ...    ...     ...     ...
# 19089  19090  0.000009   udp     dns   INT      2      0     114       0
# 35750  35751  0.001586   udp       -   CON      4      4     528     304
# 2752    2753  0.000008  unas       -   INT      2      0     200       0
# 24806  24807  9.910702   tcp       -   FIN    334    630   18892  802266
# 75410  75411  0.874563   tcp    http   FIN     10      8     820    1084
#
#                rate  ...  ct_dst_sport_ltm  ct_dst_src_ltm  is_ftp_login  \
# 1705   1.111111e+05  ...                 1               6             0
# 10166  7.910022e+01  ...                 1               1             0
# 72936  7.435927e+00  ...                 1               1             0
# 38444  2.705140e+03  ...                 1               1             0
# 19574  1.000000e+06  ...                 2              33             0
# ...             ...  ...               ...             ...           ...
# 19089  1.111111e+05  ...                20              27             0
# 35750  4.413619e+03  ...                 1               3             0
# 2752   1.250000e+05  ...                 2               5             0
# 24806  9.716769e+01  ...                 1               1             0
# 75410  1.943828e+01  ...                 2               3             0
#
#        ct_ftp_cmd  ct_flw_http_mthd  ct_src_ltm  ct_srv_dst  is_sm_ips_ports  \
# 1705            0                 0           1           6                0
# 10166           0                 1           1           1                0
# 72936           0                 0           1           1                0
# 38444           0                 0           2           4                0
# 19574           0                 0           2          33                0
# ...           ...               ...         ...         ...              ...
# 19089           0                 0          20          27                0
# 35750           0                 0           7          11                0
# 2752            0                 0          11           5                0
# 24806           0                 0           2           3                0
# 75410           0                 4           2           3                0
#
#        attack_cat  label
# 1705     Exploits      1
# 10166         DoS      1
# 72936      Normal      0
# 38444      Normal      0
# 19574     Generic      1
# ...           ...    ...
# 19089     Generic      1
# 35750      Normal      0
# 2752      Fuzzers      1
# 24806      Normal      0
# 75410      Normal      0
#
# [78215 rows x 45 columns]

# %%
_x
# Out:
#           id       dur proto service state  spkts  dpkts  sbytes  dbytes  \
# 5530    5531  0.393871   tcp     ftp   FIN     14     12    2566     702
# 35210  35211  0.018937   tcp       -   FIN     48     50    2958   32368
# 60106  60107  0.000010   udp     dns   INT      2      0     114       0
# 21666  21667  0.000009   udp     dns   INT      2      0     114       0
# 81768  81769  0.136302   tcp       -   CON      6      2     998      86
# ...      ...       ...   ...     ...   ...    ...    ...     ...     ...
# 53011  53012  0.000011  unas       -   INT      2      0     200       0
# 49977  49978  0.596275   tcp    http   FIN     10      8     858    2778
# 6625    6626  0.182411   tcp    http   FIN     10      6     916     268
# 50441  50442  1.029127   tcp     ftp   FIN     12     12     826     682
# 78133  78134  0.773097   tcp       -   FIN     10      6     660     268
#
#                 rate  ...  ct_dst_sport_ltm  ct_dst_src_ltm  is_ftp_login  \
# 5530       63.472557  ...                 1               1             0
# 35210    5122.247684  ...                 1               1             0
# 60106  100000.002500  ...                 4               4             0
# 21666  111111.107200  ...                25              43             0
# 81768      51.356549  ...                 1               5             0
# ...              ...  ...               ...             ...           ...
# 53011   90909.090200  ...                 2               2             0
# 49977      28.510336  ...                 1               1             0
# 6625       82.231883  ...                 1               1             0
# 50441      22.349039  ...                 1               1             0
# 78133      19.402482  ...                 1               3             0
#
#        ct_ftp_cmd  ct_flw_http_mthd  ct_src_ltm  ct_srv_dst  is_sm_ips_ports  \
# 5530            0                 0           1           1                0
# 35210           0                 0           6           6                0
# 60106           0                 0           4          18                0
# 21666           0                 0          25          43                0
# 81768           0                 0           1           5                0
# ...           ...               ...         ...         ...              ...
# 53011           0                 0           5           6                0
# 49977           0                 0           1           1                0
# 6625            0                 1           1           2                0
# 50441           0                 0           2           3                0
# 78133           0                 0           2           3                0
#
#        attack_cat  label
# 5530     Exploits      1
# 35210      Normal      0
# 60106     Generic      1
# 21666     Generic      1
# 81768      Normal      0
# ...           ...    ...
# 53011    Exploits      1
# 49977    Exploits      1
# 6625     Exploits      1
# 50441     Fuzzers      1
# 78133      Normal      0
#
# [4117 rows x 45 columns]

# %%
csv_save_zip(x, 'training-set_0')

# %%
csv_save_zip(_x, 'training-set_1')

# %%
x['type'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'type'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 x['type'].value_counts()
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:4090, in DataFrame.__getitem__(self, key)
#    4088 if self.columns.nlevels > 1:
#    4089     return self._getitem_multilevel(key)
# -> 4090 indexer = self.columns.get_loc(key)
#    4091 if is_integer(indexer):
#    4092     indexer = [indexer]
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'type'

# %%
values = df[output].value_counts()

for key, count in values.items():
    df_key = df[df[output] == key]
# Out:
# src_ip                    34955
# src_port                  34955
# dst_ip                    34955
# dst_port                  34955
# proto                     34955
# service                   34955
# duration                  34955
# src_bytes                 34955
# dst_bytes                 34955
# conn_state                34955
# missed_bytes              34955
# src_pkts                  34955
# src_ip_bytes              34955
# dst_pkts                  34955
# dst_ip_bytes              34955
# dns_query                 34955
# dns_qclass                34955
# dns_qtype                 34955
# dns_rcode                 34955
# dns_AA                    34955
# dns_RD                    34955
# dns_RA                    34955
# dns_rejected              34955
# ssl_version               34955
# ssl_cipher                34955
# ssl_resumed               34955
# ssl_established           34955
# ssl_subject               34955
# ssl_issuer                34955
# http_trans_depth          34955
# http_method               34955
# http_uri                  34955
# http_version              34955
# http_request_body_len     34955
# http_response_body_len    34955
# http_status_code          34955
# http_user_agent           34955
# http_orig_mime_types      34955
# http_resp_mime_types      34955
# weird_name                34955
# weird_addl                34955
# weird_notice              34955
# label                     34955
# type                      34955
# dtype: int64
# src_ip                    14102
# src_port                  14102
# dst_ip                    14102
# dst_port                  14102
# proto                     14102
# service                   14102
# duration                  14102
# src_bytes                 14102
# dst_bytes                 14102
# conn_state                14102
# missed_bytes              14102
# src_pkts                  14102
# src_ip_bytes              14102
# dst_pkts                  14102
# dst_ip_bytes              14102
# dns_query                 14102
# dns_qclass                14102
# dns_qtype                 14102
# dns_rcode                 14102
# dns_AA                    14102
# dns_RD                    14102
# dns_RA                    14102
# dns_rejected              14102
# ssl_version               14102
# ssl_cipher                14102
# ssl_resumed               14102
# ssl_established           14102
# ssl_subject               14102
# ssl_issuer                14102
# http_trans_depth          14102
# http_method               14102
# http_uri                  14102
# http_version              14102
# http_request_body_len     14102
# http_response_body_len    14102
# http_status_code          14102
# http_user_agent           14102
# http_orig_mime_types      14102
# http_resp_mime_types      14102
# weird_name                14102
# weird_addl                14102
# weird_notice              14102
# label                     14102
# type                      14102
# dtype: int64
# src_ip                    14094
# src_port                  14094
# dst_ip                    14094
# dst_port                  14094
# proto                     14094
# service                   14094
# duration                  14094
# src_bytes                 14094
# dst_bytes                 14094
# conn_state                14094
# missed_bytes              14094
# src_pkts                  14094
# src_ip_bytes              14094
# dst_pkts                  14094
# dst_ip_bytes              14094
# dns_query                 14094
# dns_qclass                14094
# dns_qtype                 14094
# dns_rcode                 14094
# dns_AA                    14094
# dns_RD                    14094
# dns_RA                    14094
# dns_rejected              14094
# ssl_version               14094
# ssl_cipher                14094
# ssl_resumed               14094
# ssl_established           14094
# ssl_subject               14094
# ssl_issuer                14094
# http_trans_depth          14094
# http_method               14094
# http_uri                  14094
# http_version              14094
# http_request_body_len     14094
# http_response_body_len    14094
# http_status_code          14094
# http_user_agent           14094
# http_orig_mime_types      14094
# http_resp_mime_types      14094
# weird_name                14094
# weird_addl                14094
# weird_notice              14094
# label                     14094
# type                      14094
# dtype: int64
# src_ip                    14028
# src_port                  14028
# dst_ip                    14028
# dst_port                  14028
# proto                     14028
# service                   14028
# duration                  14028
# src_bytes                 14028
# dst_bytes                 14028
# conn_state                14028
# missed_bytes              14028
# src_pkts                  14028
# src_ip_bytes              14028
# dst_pkts                  14028
# dst_ip_bytes              14028
# dns_query                 14028
# dns_qclass                14028
# dns_qtype                 14028
# dns_rcode                 14028
# dns_AA                    14028
# dns_RD                    14028
# dns_RA                    14028
# dns_rejected              14028
# ssl_version               14028
# ssl_cipher                14028
# ssl_resumed               14028
# ssl_established           14028
# ssl_subject               14028
# ssl_issuer                14028
# http_trans_depth          14028
# http_method               14028
# http_uri                  14028
# http_version              14028
# http_request_body_len     14028
# http_response_body_len    14028
# http_status_code          14028
# http_user_agent           14028
# http_orig_mime_types      14028
# http_resp_mime_types      14028
# weird_name                14028
# weird_addl                14028
# weird_notice              14028
# label                     14028
# type                      14028
# dtype: int64
# src_ip                    13993
# src_port                  13993
# dst_ip                    13993
# dst_port                  13993
# proto                     13993
# service                   13993
# duration                  13993
# src_bytes                 13993
# dst_bytes                 13993
# conn_state                13993
# missed_bytes              13993
# src_pkts                  13993
# src_ip_bytes              13993
# dst_pkts                  13993
# dst_ip_bytes              13993
# dns_query                 13993
# dns_qclass                13993
# dns_qtype                 13993
# dns_rcode                 13993
# dns_AA                    13993
# dns_RD                    13993
# dns_RA                    13993
# dns_rejected              13993
# ssl_version               13993
# ssl_cipher                13993
# ssl_resumed               13993
# ssl_established           13993
# ssl_subject               13993
# ssl_issuer                13993
# http_trans_depth          13993
# http_method               13993
# http_uri                  13993
# http_version              13993
# http_request_body_len     13993
# http_response_body_len    13993
# http_status_code          13993
# http_user_agent           13993
# http_orig_mime_types      13993
# http_resp_mime_types      13993
# weird_name                13993
# weird_addl                13993
# weird_notice              13993
# label                     13993
# type                      13993
# dtype: int64
# src_ip                    13981
# src_port                  13981
# dst_ip                    13981
# dst_port                  13981
# proto                     13981
# service                   13981
# duration                  13981
# src_bytes                 13981
# dst_bytes                 13981
# conn_state                13981
# missed_bytes              13981
# src_pkts                  13981
# src_ip_bytes              13981
# dst_pkts                  13981
# dst_ip_bytes              13981
# dns_query                 13981
# dns_qclass                13981
# dns_qtype                 13981
# dns_rcode                 13981
# dns_AA                    13981
# dns_RD                    13981
# dns_RA                    13981
# dns_rejected              13981
# ssl_version               13981
# ssl_cipher                13981
# ssl_resumed               13981
# ssl_established           13981
# ssl_subject               13981
# ssl_issuer                13981
# http_trans_depth          13981
# http_method               13981
# http_uri                  13981
# http_version              13981
# http_request_body_len     13981
# http_response_body_len    13981
# http_status_code          13981
# http_user_agent           13981
# http_orig_mime_types      13981
# http_resp_mime_types      13981
# weird_name                13981
# weird_addl                13981
# weird_notice              13981
# label                     13981
# type                      13981
# dtype: int64
# src_ip                    13975
# src_port                  13975
# dst_ip                    13975
# dst_port                  13975
# proto                     13975
# service                   13975
# duration                  13975
# src_bytes                 13975
# dst_bytes                 13975
# conn_state                13975
# missed_bytes              13975
# src_pkts                  13975
# src_ip_bytes              13975
# dst_pkts                  13975
# dst_ip_bytes              13975
# dns_query                 13975
# dns_qclass                13975
# dns_qtype                 13975
# dns_rcode                 13975
# dns_AA                    13975
# dns_RD                    13975
# dns_RA                    13975
# dns_rejected              13975
# ssl_version               13975
# ssl_cipher                13975
# ssl_resumed               13975
# ssl_established           13975
# ssl_subject               13975
# ssl_issuer                13975
# http_trans_depth          13975
# http_method               13975
# http_uri                  13975
# http_version              13975
# http_request_body_len     13975
# http_response_body_len    13975
# http_status_code          13975
# http_user_agent           13975
# http_orig_mime_types      13975
# http_resp_mime_types      13975
# weird_name                13975
# weird_addl                13975
# weird_notice              13975
# label                     13975
# type                      13975
# dtype: int64
# src_ip                    13974
# src_port                  13974
# dst_ip                    13974
# dst_port                  13974
# proto                     13974
# service                   13974
# duration                  13974
# src_bytes                 13974
# dst_bytes                 13974
# conn_state                13974
# missed_bytes              13974
# src_pkts                  13974
# src_ip_bytes              13974
# dst_pkts                  13974
# dst_ip_bytes              13974
# dns_query                 13974
# dns_qclass                13974
# dns_qtype                 13974
# dns_rcode                 13974
# dns_AA                    13974
# dns_RD                    13974
# dns_RA                    13974
# dns_rejected              13974
# ssl_version               13974
# ssl_cipher                13974
# ssl_resumed               13974
# ssl_established           13974
# ssl_subject               13974
# ssl_issuer                13974
# http_trans_depth          13974
# http_method               13974
# http_uri                  13974
# http_version              13974
# http_request_body_len     13974
# http_response_body_len    13974
# http_status_code          13974
# http_user_agent           13974
# http_orig_mime_types      13974
# http_resp_mime_types      13974
# weird_name                13974
# weird_addl                13974
# weird_notice              13974
# label                     13974
# type                      13974
# dtype: int64
# src_ip                    13907
# src_port                  13907
# dst_ip                    13907
# dst_port                  13907
# proto                     13907
# service                   13907
# duration                  13907
# src_bytes                 13907
# dst_bytes                 13907
# conn_state                13907
# missed_bytes              13907
# src_pkts                  13907
# src_ip_bytes              13907
# dst_pkts                  13907
# dst_ip_bytes              13907
# dns_query                 13907
# dns_qclass                13907
# dns_qtype                 13907
# dns_rcode                 13907
# dns_AA                    13907
# dns_RD                    13907
# dns_RA                    13907
# dns_rejected              13907
# ssl_version               13907
# ssl_cipher                13907
# ssl_resumed               13907
# ssl_established           13907
# ssl_subject               13907
# ssl_issuer                13907
# http_trans_depth          13907
# http_method               13907
# http_uri                  13907
# http_version              13907
# http_request_body_len     13907
# http_response_body_len    13907
# http_status_code          13907
# http_user_agent           13907
# http_orig_mime_types      13907
# http_resp_mime_types      13907
# weird_name                13907
# weird_addl                13907
# weird_notice              13907
# label                     13907
# type                      13907
# dtype: int64
# src_ip                    721
# src_port                  721
# dst_ip                    721
# dst_port                  721
# proto                     721
# service                   721
# duration                  721
# src_bytes                 721
# dst_bytes                 721
# conn_state                721
# missed_bytes              721
# src_pkts                  721
# src_ip_bytes              721
# dst_pkts                  721
# dst_ip_bytes              721
# dns_query                 721
# dns_qclass                721
# dns_qtype                 721
# dns_rcode                 721
# dns_AA                    721
# dns_RD                    721
# dns_RA                    721
# dns_rejected              721
# ssl_version               721
# ssl_cipher                721
# ssl_resumed               721
# ssl_established           721
# ssl_subject               721
# ssl_issuer                721
# http_trans_depth          721
# http_method               721
# http_uri                  721
# http_version              721
# http_request_body_len     721
# http_response_body_len    721
# http_status_code          721
# http_user_agent           721
# http_orig_mime_types      721
# http_resp_mime_types      721
# weird_name                721
# weird_addl                721
# weird_notice              721
# label                     721
# type                      721
# dtype: int64
