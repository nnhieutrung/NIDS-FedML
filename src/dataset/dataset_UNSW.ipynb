# %%
import pandas as pd

# %%
df = pd.read_csv("./UNSW_NB15.zip")

# %%
from sklearn.model_selection import train_test_split

# %%
output = 'attack_cat'

# %%
df[output].unique()
# Out:
# array(['Normal', 'Reconnaissance', 'Backdoor', 'DoS', 'Exploits',
#        'Analysis', 'Fuzzers', 'Worms', 'Shellcode', 'Generic'],
#       dtype=object)

# %%
df[output].value_counts()
# Out:
# attack_cat
# Normal            37000
# Generic           18871
# Exploits          11132
# Fuzzers            6062
# DoS                4089
# Reconnaissance     3496
# Analysis            677
# Backdoor            583
# Shellcode           378
# Worms                44
# Name: count, dtype: int64

# %%
col_1 = ['Analysis', 'Reconnaissance', 'Worms', 'Shellcode', 'Generic']
col_2 = ['Fuzzers',  'Backdoor', 'DoS', 'Exploits']

# %%
df_1 = df[df[output].isin(col_1)] 
df_2 = df[df[output].isin(col_2)]

# %%
df_3 = df[df[output] == 'Normal']

# %%
midpoint = len(df_3) // 2

df_1 = pd.concat([df_1, df_3.iloc[:midpoint]], axis=False)
df_2 = pd.concat([df_2, df_3.iloc[:midpoint]], axis=False)

# %%
df_1[output].count(), df_2[output].count()
# Out:
# (41966, 40366)

# %%
df_1[output].value_counts()
# Out:
# attack_cat
# Generic           18871
# Normal            18500
# Reconnaissance     3496
# Analysis            677
# Shellcode           378
# Worms                44
# Name: count, dtype: int64

# %%
df_2[output].value_counts()
# Out:
# attack_cat
# Normal      18500
# Exploits    11132
# Fuzzers      6062
# DoS          4089
# Backdoor      583
# Name: count, dtype: int64

# %%
def csv_save_zip(df, filename):
    compression_options = dict(method='zip', archive_name=f'{filename}.csv')
    df.to_csv(f'{filename}.zip', compression=compression_options, index=False)

# %%
csv_save_zip(df_1, 'training-set_0')

# %%
csv_save_zip(df_2, 'training-set_1')

# %%
x = df
y = df[output]
x, _x, y, _y = train_test_split(x, y, random_state=189, test_size=0.20, stratify=y)

# %%
x
# Out:
#           id       dur proto service state  spkts  dpkts  sbytes  dbytes  \
# 39789  39790  0.000000   arp       -   CON      2      2      56      92
# 54158  54159  0.000011   udp     dns   INT      2      0     114       0
# 81512  81513  0.871604   tcp       -   FIN     60     14   68201     612
# 76577  76578  0.947699   tcp       -   FIN     10      8    1182     354
# 61390  61391  0.000010   pvp       -   INT      2      0     200       0
# ...      ...       ...   ...     ...   ...    ...    ...     ...     ...
# 36567  36568  1.571011   tcp    http   FIN     12     14    1580    4168
# 19478  19479  0.000003   udp     dns   INT      2      0     114       0
# 78332  78333  0.000009   udp       -   INT      2      0     104       0
# 58326  58327  0.000004   udp     dns   INT      2      0     114       0
# 76572  76573  0.615567   tcp       -   FIN     10     10     608     646
#
#                 rate  ...  ct_dst_sport_ltm  ct_dst_src_ltm  is_ftp_login  \
# 39789       0.067561  ...                 2               2             0
# 54158   90909.090200  ...                 3               3             0
# 81512      83.753629  ...                 1               4             0
# 76577      17.938185  ...                 1               3             0
# 61390  100000.002500  ...                 2               2             0
# ...              ...  ...               ...             ...           ...
# 36567      15.913320  ...                 1               1             0
# 19478  333333.321500  ...                23              36             0
# 78332  111111.107200  ...                 2              11             0
# 58326  250000.000600  ...                 3               7             0
# 76572      30.865851  ...                 1               1             0
#
#        ct_ftp_cmd  ct_flw_http_mthd  ct_src_ltm  ct_srv_dst  is_sm_ips_ports  \
# 39789           0                 0           2           2                0
# 54158           0                 0          10          10                0
# 81512           0                 1           1           2                0
# 76577           0                 0           1           4                0
# 61390           0                 0           2          12                0
# ...           ...               ...         ...         ...              ...
# 36567           0                 0           1           4                0
# 19478           0                 0          24          36                0
# 78332           0                 0           4          11                0
# 58326           0                 0           7           9                0
# 76572           0                 0           1           1                0
#
#        attack_cat  label
# 39789      Normal      0
# 54158     Generic      1
# 81512      Normal      0
# 76577      Normal      0
# 61390    Analysis      1
# ...           ...    ...
# 36567      Normal      0
# 19478     Generic      1
# 78332      Normal      0
# 58326     Generic      1
# 76572      Normal      0
#
# [65865 rows x 45 columns]

# %%
_x
# Out:
#           id       dur proto service state  spkts  dpkts  sbytes  dbytes  \
# 48266  48267  0.000007  unas       -   INT      2      0     200       0
# 11553  11554  4.224510   tcp     ftp   FIN     24     24    1252    1740
# 7815    7816  0.372733   tcp       -   FIN     10      6    1200     268
# 50785  50786  0.000003  unas       -   INT      2      0     200       0
# 77493  77494  0.000005   udp       -   INT      2      0    1064       0
# ...      ...       ...   ...     ...   ...    ...    ...     ...     ...
# 23159  23160  0.000009   udp     dns   INT      2      0     114       0
# 25188  25189  4.793941   tcp     ssh   FIN    230    236   24344   29452
# 6132    6133  0.000009  unas       -   INT      2      0     200       0
# 46474  46475  1.722431   tcp       -   FIN    118     20  145341     870
# 75229  75230  0.000004   tcp       -   REQ      2      0      90       0
#
#                 rate  ...  ct_dst_sport_ltm  ct_dst_src_ltm  is_ftp_login  \
# 48266  142857.140900  ...                 2               3             0
# 11553      11.125550  ...                 1               2             1
# 7815       40.243284  ...                 1               4             0
# 50785  333333.321500  ...                 2               2             0
# 77493  200000.005100  ...                 1              35             0
# ...              ...  ...               ...             ...           ...
# 23159  111111.107200  ...                23              23             0
# 25188      96.997439  ...                 1               1             0
# 6132   111111.107200  ...                 4               8             0
# 46474      79.538748  ...                 1               1             0
# 75229  250000.000600  ...                 1              12             0
#
#        ct_ftp_cmd  ct_flw_http_mthd  ct_src_ltm  ct_srv_dst  is_sm_ips_ports  \
# 48266           0                 0          10           4                0
# 11553           1                 0           3           1                0
# 7815            0                 0           2           4                0
# 50785           0                 0           6           7                0
# 77493           0                 0          13          35                0
# ...           ...               ...         ...         ...              ...
# 23159           0                 0          23          23                0
# 25188           0                 0           2           1                0
# 6132            0                 0          13           8                0
# 46474           0                 0           2           1                0
# 75229           0                 0           4           5                0
#
#        attack_cat  label
# 48266    Analysis      1
# 11553    Exploits      1
# 7815     Exploits      1
# 50785         DoS      1
# 77493      Normal      0
# ...           ...    ...
# 23159     Generic      1
# 25188      Normal      0
# 6132          DoS      1
# 46474     Fuzzers      1
# 75229      Normal      0
#
# [16467 rows x 45 columns]

# %%
csv_save_zip(x, 'training-set_0')

# %%
csv_save_zip(_x, 'training-set_1')

# %%
x['type'].value_counts()
# Out:
# type
# normal        33207
# backdoor      13397
# dos           13389
# password      13327
# ransomware    13293
# ddos          13282
# injection     13276
# xss           13275
# scanning      13212
# mitm            685
# Name: count, dtype: int64

# %%
values = df[output].value_counts()

for key, count in values.items():
    df_key = df[df[output] == key]
# Out:
# src_ip                    34955
# src_port                  34955
# dst_ip                    34955
# dst_port                  34955
# proto                     34955
# service                   34955
# duration                  34955
# src_bytes                 34955
# dst_bytes                 34955
# conn_state                34955
# missed_bytes              34955
# src_pkts                  34955
# src_ip_bytes              34955
# dst_pkts                  34955
# dst_ip_bytes              34955
# dns_query                 34955
# dns_qclass                34955
# dns_qtype                 34955
# dns_rcode                 34955
# dns_AA                    34955
# dns_RD                    34955
# dns_RA                    34955
# dns_rejected              34955
# ssl_version               34955
# ssl_cipher                34955
# ssl_resumed               34955
# ssl_established           34955
# ssl_subject               34955
# ssl_issuer                34955
# http_trans_depth          34955
# http_method               34955
# http_uri                  34955
# http_version              34955
# http_request_body_len     34955
# http_response_body_len    34955
# http_status_code          34955
# http_user_agent           34955
# http_orig_mime_types      34955
# http_resp_mime_types      34955
# weird_name                34955
# weird_addl                34955
# weird_notice              34955
# label                     34955
# type                      34955
# dtype: int64
# src_ip                    14102
# src_port                  14102
# dst_ip                    14102
# dst_port                  14102
# proto                     14102
# service                   14102
# duration                  14102
# src_bytes                 14102
# dst_bytes                 14102
# conn_state                14102
# missed_bytes              14102
# src_pkts                  14102
# src_ip_bytes              14102
# dst_pkts                  14102
# dst_ip_bytes              14102
# dns_query                 14102
# dns_qclass                14102
# dns_qtype                 14102
# dns_rcode                 14102
# dns_AA                    14102
# dns_RD                    14102
# dns_RA                    14102
# dns_rejected              14102
# ssl_version               14102
# ssl_cipher                14102
# ssl_resumed               14102
# ssl_established           14102
# ssl_subject               14102
# ssl_issuer                14102
# http_trans_depth          14102
# http_method               14102
# http_uri                  14102
# http_version              14102
# http_request_body_len     14102
# http_response_body_len    14102
# http_status_code          14102
# http_user_agent           14102
# http_orig_mime_types      14102
# http_resp_mime_types      14102
# weird_name                14102
# weird_addl                14102
# weird_notice              14102
# label                     14102
# type                      14102
# dtype: int64
# src_ip                    14094
# src_port                  14094
# dst_ip                    14094
# dst_port                  14094
# proto                     14094
# service                   14094
# duration                  14094
# src_bytes                 14094
# dst_bytes                 14094
# conn_state                14094
# missed_bytes              14094
# src_pkts                  14094
# src_ip_bytes              14094
# dst_pkts                  14094
# dst_ip_bytes              14094
# dns_query                 14094
# dns_qclass                14094
# dns_qtype                 14094
# dns_rcode                 14094
# dns_AA                    14094
# dns_RD                    14094
# dns_RA                    14094
# dns_rejected              14094
# ssl_version               14094
# ssl_cipher                14094
# ssl_resumed               14094
# ssl_established           14094
# ssl_subject               14094
# ssl_issuer                14094
# http_trans_depth          14094
# http_method               14094
# http_uri                  14094
# http_version              14094
# http_request_body_len     14094
# http_response_body_len    14094
# http_status_code          14094
# http_user_agent           14094
# http_orig_mime_types      14094
# http_resp_mime_types      14094
# weird_name                14094
# weird_addl                14094
# weird_notice              14094
# label                     14094
# type                      14094
# dtype: int64
# src_ip                    14028
# src_port                  14028
# dst_ip                    14028
# dst_port                  14028
# proto                     14028
# service                   14028
# duration                  14028
# src_bytes                 14028
# dst_bytes                 14028
# conn_state                14028
# missed_bytes              14028
# src_pkts                  14028
# src_ip_bytes              14028
# dst_pkts                  14028
# dst_ip_bytes              14028
# dns_query                 14028
# dns_qclass                14028
# dns_qtype                 14028
# dns_rcode                 14028
# dns_AA                    14028
# dns_RD                    14028
# dns_RA                    14028
# dns_rejected              14028
# ssl_version               14028
# ssl_cipher                14028
# ssl_resumed               14028
# ssl_established           14028
# ssl_subject               14028
# ssl_issuer                14028
# http_trans_depth          14028
# http_method               14028
# http_uri                  14028
# http_version              14028
# http_request_body_len     14028
# http_response_body_len    14028
# http_status_code          14028
# http_user_agent           14028
# http_orig_mime_types      14028
# http_resp_mime_types      14028
# weird_name                14028
# weird_addl                14028
# weird_notice              14028
# label                     14028
# type                      14028
# dtype: int64
# src_ip                    13993
# src_port                  13993
# dst_ip                    13993
# dst_port                  13993
# proto                     13993
# service                   13993
# duration                  13993
# src_bytes                 13993
# dst_bytes                 13993
# conn_state                13993
# missed_bytes              13993
# src_pkts                  13993
# src_ip_bytes              13993
# dst_pkts                  13993
# dst_ip_bytes              13993
# dns_query                 13993
# dns_qclass                13993
# dns_qtype                 13993
# dns_rcode                 13993
# dns_AA                    13993
# dns_RD                    13993
# dns_RA                    13993
# dns_rejected              13993
# ssl_version               13993
# ssl_cipher                13993
# ssl_resumed               13993
# ssl_established           13993
# ssl_subject               13993
# ssl_issuer                13993
# http_trans_depth          13993
# http_method               13993
# http_uri                  13993
# http_version              13993
# http_request_body_len     13993
# http_response_body_len    13993
# http_status_code          13993
# http_user_agent           13993
# http_orig_mime_types      13993
# http_resp_mime_types      13993
# weird_name                13993
# weird_addl                13993
# weird_notice              13993
# label                     13993
# type                      13993
# dtype: int64
# src_ip                    13981
# src_port                  13981
# dst_ip                    13981
# dst_port                  13981
# proto                     13981
# service                   13981
# duration                  13981
# src_bytes                 13981
# dst_bytes                 13981
# conn_state                13981
# missed_bytes              13981
# src_pkts                  13981
# src_ip_bytes              13981
# dst_pkts                  13981
# dst_ip_bytes              13981
# dns_query                 13981
# dns_qclass                13981
# dns_qtype                 13981
# dns_rcode                 13981
# dns_AA                    13981
# dns_RD                    13981
# dns_RA                    13981
# dns_rejected              13981
# ssl_version               13981
# ssl_cipher                13981
# ssl_resumed               13981
# ssl_established           13981
# ssl_subject               13981
# ssl_issuer                13981
# http_trans_depth          13981
# http_method               13981
# http_uri                  13981
# http_version              13981
# http_request_body_len     13981
# http_response_body_len    13981
# http_status_code          13981
# http_user_agent           13981
# http_orig_mime_types      13981
# http_resp_mime_types      13981
# weird_name                13981
# weird_addl                13981
# weird_notice              13981
# label                     13981
# type                      13981
# dtype: int64
# src_ip                    13975
# src_port                  13975
# dst_ip                    13975
# dst_port                  13975
# proto                     13975
# service                   13975
# duration                  13975
# src_bytes                 13975
# dst_bytes                 13975
# conn_state                13975
# missed_bytes              13975
# src_pkts                  13975
# src_ip_bytes              13975
# dst_pkts                  13975
# dst_ip_bytes              13975
# dns_query                 13975
# dns_qclass                13975
# dns_qtype                 13975
# dns_rcode                 13975
# dns_AA                    13975
# dns_RD                    13975
# dns_RA                    13975
# dns_rejected              13975
# ssl_version               13975
# ssl_cipher                13975
# ssl_resumed               13975
# ssl_established           13975
# ssl_subject               13975
# ssl_issuer                13975
# http_trans_depth          13975
# http_method               13975
# http_uri                  13975
# http_version              13975
# http_request_body_len     13975
# http_response_body_len    13975
# http_status_code          13975
# http_user_agent           13975
# http_orig_mime_types      13975
# http_resp_mime_types      13975
# weird_name                13975
# weird_addl                13975
# weird_notice              13975
# label                     13975
# type                      13975
# dtype: int64
# src_ip                    13974
# src_port                  13974
# dst_ip                    13974
# dst_port                  13974
# proto                     13974
# service                   13974
# duration                  13974
# src_bytes                 13974
# dst_bytes                 13974
# conn_state                13974
# missed_bytes              13974
# src_pkts                  13974
# src_ip_bytes              13974
# dst_pkts                  13974
# dst_ip_bytes              13974
# dns_query                 13974
# dns_qclass                13974
# dns_qtype                 13974
# dns_rcode                 13974
# dns_AA                    13974
# dns_RD                    13974
# dns_RA                    13974
# dns_rejected              13974
# ssl_version               13974
# ssl_cipher                13974
# ssl_resumed               13974
# ssl_established           13974
# ssl_subject               13974
# ssl_issuer                13974
# http_trans_depth          13974
# http_method               13974
# http_uri                  13974
# http_version              13974
# http_request_body_len     13974
# http_response_body_len    13974
# http_status_code          13974
# http_user_agent           13974
# http_orig_mime_types      13974
# http_resp_mime_types      13974
# weird_name                13974
# weird_addl                13974
# weird_notice              13974
# label                     13974
# type                      13974
# dtype: int64
# src_ip                    13907
# src_port                  13907
# dst_ip                    13907
# dst_port                  13907
# proto                     13907
# service                   13907
# duration                  13907
# src_bytes                 13907
# dst_bytes                 13907
# conn_state                13907
# missed_bytes              13907
# src_pkts                  13907
# src_ip_bytes              13907
# dst_pkts                  13907
# dst_ip_bytes              13907
# dns_query                 13907
# dns_qclass                13907
# dns_qtype                 13907
# dns_rcode                 13907
# dns_AA                    13907
# dns_RD                    13907
# dns_RA                    13907
# dns_rejected              13907
# ssl_version               13907
# ssl_cipher                13907
# ssl_resumed               13907
# ssl_established           13907
# ssl_subject               13907
# ssl_issuer                13907
# http_trans_depth          13907
# http_method               13907
# http_uri                  13907
# http_version              13907
# http_request_body_len     13907
# http_response_body_len    13907
# http_status_code          13907
# http_user_agent           13907
# http_orig_mime_types      13907
# http_resp_mime_types      13907
# weird_name                13907
# weird_addl                13907
# weird_notice              13907
# label                     13907
# type                      13907
# dtype: int64
# src_ip                    721
# src_port                  721
# dst_ip                    721
# dst_port                  721
# proto                     721
# service                   721
# duration                  721
# src_bytes                 721
# dst_bytes                 721
# conn_state                721
# missed_bytes              721
# src_pkts                  721
# src_ip_bytes              721
# dst_pkts                  721
# dst_ip_bytes              721
# dns_query                 721
# dns_qclass                721
# dns_qtype                 721
# dns_rcode                 721
# dns_AA                    721
# dns_RD                    721
# dns_RA                    721
# dns_rejected              721
# ssl_version               721
# ssl_cipher                721
# ssl_resumed               721
# ssl_established           721
# ssl_subject               721
# ssl_issuer                721
# http_trans_depth          721
# http_method               721
# http_uri                  721
# http_version              721
# http_request_body_len     721
# http_response_body_len    721
# http_status_code          721
# http_user_agent           721
# http_orig_mime_types      721
# http_resp_mime_types      721
# weird_name                721
# weird_addl                721
# weird_notice              721
# label                     721
# type                      721
# dtype: int64
